# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Munic%C3%ADpio'

data = requests.get(url)

dados = data.json()

df = pd.DataFrame(dados['items'])

df
# Out:
#      id_pleito tipo_interessado             interessado  cod_ibge  uf  \
# 0        12093        Município                 Resende   3304201  RJ
# 1        13574        Município          Rio de Janeiro   3304557  RJ
# 2        13784        Município  Santo Antônio de Pádua   3304706  RJ
# 3        12404        Município                 Resende   3304201  RJ
# 4        11202        Município          Rio de Janeiro   3304557  RJ
# ..         ...              ...                     ...       ...  ..
# 230       9096        Município                Cordeiro   3301504  RJ
# 231      10396        Município             São Gonçalo   3304904  RJ
# 232       5689        Município               Rio Claro   3304409  RJ
# 233      22824        Município          Rio de Janeiro   3304557  RJ
# 234       9308        Município             Nova Iguaçu   3303500  RJ
#
#                   num_pvl                                             status  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_pleito              235 non-null    int64
#  1   tipo_interessado       235 non-null    object
#  2   interessado            235 non-null    object
#  3   cod_ibge               235 non-null    int64
#  4   uf                     235 non-null    object
#  5   num_pvl                58 non-null     object
#  6   status                 235 non-null    object
#  7   num_processo           218 non-null    object
#  8   data_protocolo         218 non-null    object
#  9   tipo_operacao          235 non-null    object
#  10  finalidade             235 non-null    object
#  11  tipo_credor            235 non-null    object
#  12  credor                 235 non-null    object
#  13  moeda                  235 non-null    object
# ...

# %%
# 2) Seu código aqui
status = df['status'].value_counts()
status
# Out:
# Deferido                                                 94
# Arquivado                                                53
# Regularizado                                             25
# Arquivado por decurso de prazo                           23
# Deferido (PVL-IF)                                        16
# Encaminhado à PGFN com manifestação técnica favorável    13
# Arquivado a pedido                                        6
# Em retificação pelo interessado                           3
# Em retificação pelo interessado (PVL-IF)                  1
# Pendente de regularização                                 1
# Name: status, dtype: int64

# %%
frequencia = (status/235)
frequencia
# Out:
# Deferido                                                 0.400000
# Arquivado                                                0.225532
# Regularizado                                             0.106383
# Arquivado por decurso de prazo                           0.097872
# Deferido (PVL-IF)                                        0.068085
# Encaminhado à PGFN com manifestação técnica favorável    0.055319
# Arquivado a pedido                                       0.025532
# Em retificação pelo interessado                          0.012766
# Em retificação pelo interessado (PVL-IF)                 0.004255
# Pendente de regularização                                0.004255
# Name: status, dtype: float64

# %%
# 3) Seu código aqui
dataStatus = df['data_status']

datas = dataStatus.str

ano = pd.Series.str.slice(datas, start = 6)

ano
# Out:
# 0      2014
# 1      2010
# 2      2020
# 3      2020
# 4      2013
#        ...
# 230    2014
# 231    2022
# 232    2008
# 233    2021
# 234    2007
# Name: data_status, Length: 235, dtype: object

# %%
frequencia_ano = ano.value_counts()

frequencia_ano = frequencia_ano/235

frequencia_ano
# Out:
# 2008    0.157447
# 2007    0.123404
# 2014    0.085106
# 2010    0.080851
# 2019    0.072340
# 2020    0.063830
# 2013    0.063830
# 2022    0.059574
# 2012    0.055319
# 2011    0.042553
# 2015    0.038298
# 2009    0.038298
# 2021    0.021277
# 2017    0.021277
# 2002    0.017021
# 2006    0.017021
# 2018    0.017021
# 2016    0.017021
# 2003    0.004255
# 2004    0.004255
# Name: data_status, dtype: float64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def Busca_dados(estado, interessado):
    tipo_interessado = interessado
    escolhe_estado = estado
    if tipo_interessado == 'municipio':
        tipo_interessado ='Munic%C3%ADpio'
    
    url =f'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf={estado}&tipo_interessado={tipo_interessado}'
    
    data = requests.get(url)

    dados = data.json()

    df = pd.DataFrame(dados['items'])

    return df
data_frame = Busca_dados('RJ', 'Estado')

data_frame
# Out:
#     id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0       11306           Estado  Rio de Janeiro        33  RJ
# 1       22594           Estado  Rio de Janeiro        33  RJ
# 2       10606           Estado  Rio de Janeiro        33  RJ
# 3       10673           Estado  Rio de Janeiro        33  RJ
# 4        7187           Estado  Rio de Janeiro        33  RJ
# 5        5933           Estado  Rio de Janeiro        33  RJ
# 6        5952           Estado  Rio de Janeiro        33  RJ
# 7        9042           Estado  Rio de Janeiro        33  RJ
# 8        7150           Estado  Rio de Janeiro        33  RJ
# 9        7525           Estado  Rio de Janeiro        33  RJ
# 10      10849           Estado  Rio de Janeiro        33  RJ
# 11      11961           Estado  Rio de Janeiro        33  RJ
# 12      13634           Estado  Rio de Janeiro        33  RJ
# 13       5943           Estado  Rio de Janeiro        33  RJ
# ...

# %%
# 2) Seu código aqui
df = Busca_dados('MG', 'Estado')
df_arquivados = df[df['status'] =='Arquivado por decurso de prazo']
df_arquivados

#Existe apenas uma solicitação com status em 'Arquivado por decurso de prazo' registrada
# Out:
#     id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 35      20534           Estado  Minas Gerais        31  MG
#
#                  num_pvl                          status  \
# 35  00000.000000/2017-69  Arquivado por decurso de prazo
#
#             num_processo        data_protocolo                tipo_operacao  \
# 35  17944.001113/2015-60  2017-07-26T03:00:00Z  Operação contratual interna
#
#    finalidade                      tipo_credor  \
# 35       PMAE  Instituição Financeira Nacional
#
#                                                credor moeda      valor  \
# 35  Banco Nacional de Desenvolvimento Econômico e ...  Real  7668000.0
#
#     pvl_assoc_divida  pvl_contradado_credor data_status
# 35                 0                      0  16/03/2018

# %%
# 3) Seu código aqui
df_bahia = Busca_dados('BA', 'municipio')
df_deferidos = df_bahia[df_bahia['status'] == 'Deferido']
df_deferidos['interessado'].value_counts()

# O município com mais solicitações deferidas é Luís Eduardo Magalhães
# Out:
# Luís Eduardo Magalhães    14
# Vitória da Conquista      11
# Camaçari                  10
# Lauro de Freitas          10
# Barreiras                  9
#                           ..
# Andorinha                  1
# Boa Vista do Tupim         1
# Paramirim                  1
# Santa Maria da Vitória     1
# Cafarnaum                  1
# Name: interessado, Length: 176, dtype: int64

# %%
# 4) Seu código aqui
df_bahia = Busca_dados('BA', 'Estado')
df_bahia
df_bahia.to_csv('dataframe_bahia_estado.csv')
